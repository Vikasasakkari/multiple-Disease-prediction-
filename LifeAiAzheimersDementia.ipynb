# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2
import itertools
import pathlib
import warnings
from PIL import Image
from random import randint
warnings.filterwarnings('ignore')
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow import keras
from keras import layers
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras.utils.vis_utils import plot_model
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator as IDG
from tensorflow.keras.layers import SeparableConv2D, BatchNormalization, GlobalAveragePooling2D
from distutils.dir_util import copy_tree, remove_tree

import os
print(os.listdir("C:\\Users\\anany"))

print("TensorFlow Version:", tf.__version__)
# Out:
# ['AugmentedAlzheimerDataset', 'OriginalDataset']
# TensorFlow Version: 2.12.0

# %%
import splitfolders
splitfolders.ratio('C:\\Users\\anany', output="output", seed=1345, ratio=(.8, 0.1,0.1))

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
"C:\\Users\\anany\\OriginalDataset",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
"C:\\Users\\anany\\AugmentedAlzheimerDataset",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
"C:\\Users\\anany\\AugmentedAlzheimerDataset",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)
# Out:
# Found 6400 files belonging to 4 classes.
# Found 33984 files belonging to 4 classes.
# Found 33984 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
train_ds
# Out:
# ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = [896,64,3200,2240]
ax.bar(class_names,size)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model = keras.models.Sequential()
model.add(keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)))
model.add(keras.layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))


model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.20))

model.add(keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128,activation="relu",kernel_initializer="he_normal"))
model.add(keras.layers.Dense(64,"relu"))
model.add(keras.layers.Dense(4,"softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer = "Adam",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2,129,380
# Trainable params: 2,129,380
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(train_ds,validation_data=val_ds,epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 210s 2s/step - loss: 1.3567 - accuracy: 0.4934 - val_loss: 1.5048 - val_accuracy: 0.3036
# Epoch 2/100
# 100/100 [==============================] - 207s 2s/step - loss: 0.9510 - accuracy: 0.5502 - val_loss: 1.5195 - val_accuracy: 0.3448
# Epoch 3/100
# 100/100 [==============================] - 262s 3s/step - loss: 0.8991 - accuracy: 0.5747 - val_loss: 1.3868 - val_accuracy: 0.3535
# Epoch 4/100
# 100/100 [==============================] - 261s 3s/step - loss: 0.8425 - accuracy: 0.6055 - val_loss: 1.3123 - val_accuracy: 0.4336
# Epoch 5/100
# 100/100 [==============================] - 312s 3s/step - loss: 0.7660 - accuracy: 0.6534 - val_loss: 1.3232 - val_accuracy: 0.4611
# Epoch 6/100
# 100/100 [==============================] - 227s 2s/step - loss: 0.6974 - accuracy: 0.6870 - val_loss: 1.2695 - val_accuracy: 0.5398
# Epoch 7/100
# 100/100 [==============================] - 155s 2s/step - loss: 0.5963 - accuracy: 0.7397 - val_loss: 1.3523 - val_accuracy: 0.5553
# Epoch 8/100
# 100/100 [==============================] - 186s 2s/step - loss: 0.4908 - accuracy: 0.7909 - val_loss: 1.3272 - val_accuracy: 0.5975
# Epoch 9/100
# 100/100 [==============================] - 294s 3s/step - loss: 0.4321 - accuracy: 0.8263 - val_loss: 1.4351 - val_accuracy: 0.6254
# Epoch 10/100
# 100/100 [==============================] - 185s 2s/step - loss: 0.3507 - accuracy: 0.8562 - val_loss: 1.4754 - val_accuracy: 0.6354
# Epoch 11/100
# 100/100 [==============================] - 200s 2s/step - loss: 0.2792 - accuracy: 0.8903 - val_loss: 1.3803 - val_accuracy: 0.6605
# Epoch 12/100
# 100/100 [==============================] - 154s 2s/step - loss: 0.2388 - accuracy: 0.9100 - val_loss: 1.4263 - val_accuracy: 0.6607
# Epoch 13/100
# 100/100 [==============================] - 156s 2s/step - loss: 0.1785 - accuracy: 0.9330 - val_loss: 1.7870 - val_accuracy: 0.6416
# Epoch 14/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.1578 - accuracy: 0.9425 - val_loss: 1.5817 - val_accuracy: 0.6679
# Epoch 15/100
# 100/100 [==============================] - 154s 2s/step - loss: 0.1393 - accuracy: 0.9491 - val_loss: 1.8022 - val_accuracy: 0.6678
# Epoch 16/100
# 100/100 [==============================] - 152s 2s/step - loss: 0.1180 - accuracy: 0.9581 - val_loss: 1.6217 - val_accuracy: 0.6797
# Epoch 17/100
# 100/100 [==============================] - 151s 2s/step - loss: 0.0928 - accuracy: 0.9681 - val_loss: 1.8999 - val_accuracy: 0.6710
# Epoch 18/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0845 - accuracy: 0.9697 - val_loss: 1.8787 - val_accuracy: 0.6623
# Epoch 19/100
# 100/100 [==============================] - 154s 2s/step - loss: 0.0748 - accuracy: 0.9727 - val_loss: 1.9964 - val_accuracy: 0.6804
# Epoch 20/100
# 100/100 [==============================] - 156s 2s/step - loss: 0.0618 - accuracy: 0.9780 - val_loss: 2.1653 - val_accuracy: 0.6576
# Epoch 21/100
# 100/100 [==============================] - 154s 2s/step - loss: 0.0646 - accuracy: 0.9767 - val_loss: 1.7398 - val_accuracy: 0.6806
# Epoch 22/100
# 100/100 [==============================] - 154s 2s/step - loss: 0.0645 - accuracy: 0.9769 - val_loss: 1.9086 - val_accuracy: 0.6781
# Epoch 23/100
# 100/100 [==============================] - 153s 2s/step - loss: 0.0486 - accuracy: 0.9819 - val_loss: 1.6932 - val_accuracy: 0.6902
# Epoch 24/100
# 100/100 [==============================] - 151s 2s/step - loss: 0.0557 - accuracy: 0.9791 - val_loss: 1.8314 - val_accuracy: 0.6900
# Epoch 25/100
# 100/100 [==============================] - 153s 2s/step - loss: 0.0522 - accuracy: 0.9820 - val_loss: 1.9323 - val_accuracy: 0.6875
# Epoch 26/100
# 100/100 [==============================] - 154s 2s/step - loss: 0.0471 - accuracy: 0.9812 - val_loss: 1.8142 - val_accuracy: 0.6884
# Epoch 27/100
# 100/100 [==============================] - 155s 2s/step - loss: 0.0367 - accuracy: 0.9889 - val_loss: 1.9364 - val_accuracy: 0.6799
# Epoch 28/100
# 100/100 [==============================] - 152s 2s/step - loss: 0.0515 - accuracy: 0.9816 - val_loss: 1.8334 - val_accuracy: 0.6830
# Epoch 29/100
# 100/100 [==============================] - 151s 2s/step - loss: 0.0382 - accuracy: 0.9883 - val_loss: 2.3008 - val_accuracy: 0.6650
# Epoch 30/100
# 100/100 [==============================] - 153s 2s/step - loss: 0.0344 - accuracy: 0.9892 - val_loss: 1.8783 - val_accuracy: 0.6956
# Epoch 31/100
# 100/100 [==============================] - 152s 2s/step - loss: 0.0303 - accuracy: 0.9889 - val_loss: 2.0358 - val_accuracy: 0.6765
# Epoch 32/100
# 100/100 [==============================] - 152s 2s/step - loss: 0.0388 - accuracy: 0.9859 - val_loss: 1.7527 - val_accuracy: 0.6936
# Epoch 33/100
# 100/100 [==============================] - 152s 2s/step - loss: 0.0391 - accuracy: 0.9853 - val_loss: 1.7830 - val_accuracy: 0.7004
# Epoch 34/100
# 100/100 [==============================] - 152s 2s/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 1.9128 - val_accuracy: 0.6923
# Epoch 35/100
# 100/100 [==============================] - 150s 2s/step - loss: 0.0194 - accuracy: 0.9941 - val_loss: 2.1524 - val_accuracy: 0.6902
# Epoch 36/100
# 100/100 [==============================] - 152s 2s/step - loss: 0.0279 - accuracy: 0.9906 - val_loss: 2.0293 - val_accuracy: 0.6882
# Epoch 37/100
# 100/100 [==============================] - 153s 2s/step - loss: 0.0317 - accuracy: 0.9892 - val_loss: 2.0271 - val_accuracy: 0.6936
# Epoch 38/100
# 100/100 [==============================] - 153s 2s/step - loss: 0.0183 - accuracy: 0.9936 - val_loss: 2.2162 - val_accuracy: 0.6933
# Epoch 39/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0269 - accuracy: 0.9891 - val_loss: 1.9801 - val_accuracy: 0.7012
# Epoch 40/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 2.2446 - val_accuracy: 0.6822
# Epoch 41/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0324 - accuracy: 0.9886 - val_loss: 1.9353 - val_accuracy: 0.6873
# Epoch 42/100
# 100/100 [==============================] - 155s 2s/step - loss: 0.0214 - accuracy: 0.9923 - val_loss: 2.0396 - val_accuracy: 0.6907
# Epoch 43/100
# 100/100 [==============================] - 156s 2s/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 2.2708 - val_accuracy: 0.6797
# Epoch 44/100
# 100/100 [==============================] - 153s 2s/step - loss: 0.0273 - accuracy: 0.9906 - val_loss: 2.1959 - val_accuracy: 0.6941
# Epoch 45/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0177 - accuracy: 0.9930 - val_loss: 2.4006 - val_accuracy: 0.6717
# Epoch 46/100
# 100/100 [==============================] - 150s 2s/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 2.1171 - val_accuracy: 0.6903
# Epoch 47/100
# 100/100 [==============================] - 180s 2s/step - loss: 0.0271 - accuracy: 0.9908 - val_loss: 2.2971 - val_accuracy: 0.6814
# Epoch 48/100
# 100/100 [==============================] - 208s 2s/step - loss: 0.0227 - accuracy: 0.9922 - val_loss: 2.1448 - val_accuracy: 0.6851
# Epoch 49/100
# 100/100 [==============================] - 303s 3s/step - loss: 0.0206 - accuracy: 0.9930 - val_loss: 2.1352 - val_accuracy: 0.7025
# Epoch 50/100
# 100/100 [==============================] - 189s 2s/step - loss: 0.0214 - accuracy: 0.9922 - val_loss: 2.5298 - val_accuracy: 0.6813
# Epoch 51/100
# 100/100 [==============================] - 155s 2s/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 2.4726 - val_accuracy: 0.6843
# Epoch 52/100
# 100/100 [==============================] - 147s 1s/step - loss: 0.0304 - accuracy: 0.9900 - val_loss: 1.8297 - val_accuracy: 0.6933
# Epoch 53/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0147 - accuracy: 0.9952 - val_loss: 2.2347 - val_accuracy: 0.6934
# Epoch 54/100
# 100/100 [==============================] - 160s 2s/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 2.4782 - val_accuracy: 0.6802
# Epoch 55/100
# 100/100 [==============================] - 183s 2s/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 2.0226 - val_accuracy: 0.6977
# Epoch 56/100
# 100/100 [==============================] - 160s 2s/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 2.0767 - val_accuracy: 0.6891
# Epoch 57/100
# 100/100 [==============================] - 167s 2s/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 2.0906 - val_accuracy: 0.6964
# Epoch 58/100
# 100/100 [==============================] - 156s 2s/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 2.1999 - val_accuracy: 0.7048
# Epoch 59/100
# 100/100 [==============================] - 152s 2s/step - loss: 0.0440 - accuracy: 0.9853 - val_loss: 1.9496 - val_accuracy: 0.6920
# Epoch 60/100
# 100/100 [==============================] - 152s 2s/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 2.0350 - val_accuracy: 0.7090
# Epoch 61/100
# 100/100 [==============================] - 150s 2s/step - loss: 0.0215 - accuracy: 0.9914 - val_loss: 2.0848 - val_accuracy: 0.6994
# Epoch 62/100
# 100/100 [==============================] - 150s 2s/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 2.1612 - val_accuracy: 0.6873
# Epoch 63/100
# 100/100 [==============================] - 151s 2s/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 2.1495 - val_accuracy: 0.7080
# Epoch 64/100
# 100/100 [==============================] - 149s 1s/step - loss: 0.0289 - accuracy: 0.9897 - val_loss: 2.1829 - val_accuracy: 0.7021
# Epoch 65/100
# 100/100 [==============================] - 150s 2s/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 1.9685 - val_accuracy: 0.6896
# Epoch 66/100
# 100/100 [==============================] - 151s 2s/step - loss: 0.0100 - accuracy: 0.9967 - val_loss: 2.1793 - val_accuracy: 0.7025
# Epoch 67/100
# 100/100 [==============================] - 153s 2s/step - loss: 0.0174 - accuracy: 0.9931 - val_loss: 2.1926 - val_accuracy: 0.6542
# Epoch 68/100
# 100/100 [==============================] - 150s 2s/step - loss: 0.0140 - accuracy: 0.9945 - val_loss: 2.1767 - val_accuracy: 0.7015
# Epoch 69/100
# 100/100 [==============================] - 151s 2s/step - loss: 0.0176 - accuracy: 0.9939 - val_loss: 2.5011 - val_accuracy: 0.6922
# Epoch 70/100
# 100/100 [==============================] - 150s 2s/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 2.4092 - val_accuracy: 0.6960
# Epoch 71/100
# 100/100 [==============================] - 151s 2s/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 2.2908 - val_accuracy: 0.6708
# Epoch 72/100
# 100/100 [==============================] - 153s 2s/step - loss: 0.0112 - accuracy: 0.9953 - val_loss: 2.5258 - val_accuracy: 0.6926
# Epoch 73/100
# 100/100 [==============================] - 153s 2s/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 2.1595 - val_accuracy: 0.7029
# Epoch 74/100
# 100/100 [==============================] - 149s 1s/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 2.5412 - val_accuracy: 0.6991
# Epoch 75/100
# 100/100 [==============================] - 149s 1s/step - loss: 0.0125 - accuracy: 0.9967 - val_loss: 2.2242 - val_accuracy: 0.6910
# Epoch 76/100
# 100/100 [==============================] - 147s 1s/step - loss: 0.0137 - accuracy: 0.9948 - val_loss: 2.4799 - val_accuracy: 0.6887
# Epoch 77/100
# 100/100 [==============================] - 148s 1s/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 2.0601 - val_accuracy: 0.7066
# Epoch 78/100
# 100/100 [==============================] - 147s 1s/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 2.2493 - val_accuracy: 0.6890
# Epoch 79/100
# 100/100 [==============================] - 148s 1s/step - loss: 0.0261 - accuracy: 0.9917 - val_loss: 1.9874 - val_accuracy: 0.6865
# Epoch 80/100
# 100/100 [==============================] - 150s 2s/step - loss: 0.0149 - accuracy: 0.9941 - val_loss: 2.2714 - val_accuracy: 0.6992
# Epoch 81/100
# 100/100 [==============================] - 145s 1s/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 2.7373 - val_accuracy: 0.6849
# Epoch 82/100
# 100/100 [==============================] - 142s 1s/step - loss: 0.0301 - accuracy: 0.9894 - val_loss: 1.9598 - val_accuracy: 0.7071
# Epoch 83/100
# 100/100 [==============================] - 143s 1s/step - loss: 0.0123 - accuracy: 0.9952 - val_loss: 2.0089 - val_accuracy: 0.7085
# Epoch 84/100
# 100/100 [==============================] - 142s 1s/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 3.1740 - val_accuracy: 0.6867
# Epoch 85/100
# 100/100 [==============================] - 154s 2s/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 2.8628 - val_accuracy: 0.6829
# Epoch 86/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 2.5887 - val_accuracy: 0.6869
# Epoch 87/100
# 100/100 [==============================] - 161s 2s/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 2.4320 - val_accuracy: 0.7043
# Epoch 88/100
# 100/100 [==============================] - 162s 2s/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 2.4082 - val_accuracy: 0.6945
# Epoch 89/100
# 100/100 [==============================] - 159s 2s/step - loss: 0.0122 - accuracy: 0.9956 - val_loss: 2.2494 - val_accuracy: 0.6934
# Epoch 90/100
# 100/100 [==============================] - 159s 2s/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 2.1435 - val_accuracy: 0.6954
# Epoch 91/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0256 - accuracy: 0.9917 - val_loss: 1.8670 - val_accuracy: 0.7119
# Epoch 92/100
# 100/100 [==============================] - 158s 2s/step - loss: 0.0141 - accuracy: 0.9950 - val_loss: 2.9097 - val_accuracy: 0.6971
# Epoch 93/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 2.8507 - val_accuracy: 0.7022
# Epoch 94/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0087 - accuracy: 0.9964 - val_loss: 2.9589 - val_accuracy: 0.6949
# Epoch 95/100
# 100/100 [==============================] - 162s 2s/step - loss: 0.0151 - accuracy: 0.9945 - val_loss: 2.1749 - val_accuracy: 0.7034
# Epoch 96/100
# 100/100 [==============================] - 158s 2s/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 2.3134 - val_accuracy: 0.6958
# Epoch 97/100
# 100/100 [==============================] - 159s 2s/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 2.4240 - val_accuracy: 0.7025
# Epoch 98/100
# 100/100 [==============================] - 157s 2s/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 2.4089 - val_accuracy: 0.6918
# Epoch 99/100
# 100/100 [==============================] - 158s 2s/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 2.2809 - val_accuracy: 0.7097
# Epoch 100/100
# 100/100 [==============================] - 158s 2s/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 2.5062 - val_accuracy: 0.7081

# %%
get_ac = hist.history['accuracy']
get_los = hist.history['loss']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']
epochs = range(len(get_ac))
plt.plot(epochs, get_ac, 'g', label='Accuracy of Training data')
plt.plot(epochs, get_los, 'r', label='Loss of Training data')
plt.title('Training data accuracy and loss')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_ac, 'g', label='Accuracy of Training Data')
plt.plot(epochs, val_acc, 'r', label='Accuracy of Validation Data')
plt.title('Training and Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_los, 'g', label='Loss of Training Data')
plt.plot(epochs, val_loss, 'r', label='Loss of Validation Data')
plt.title('Training and Validation Loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
loss, accuracy = model.evaluate(test_ds)
# Out:
# 531/531 [==============================] - 214s 403ms/step - loss: 2.5062 - accuracy: 0.7081

# %%
plt.figure(figsize=(20, 20))
for images, labels in test_ds.take(1):
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predictions = model.predict(tf.expand_dims(images[i], 0))
        score = tf.nn.softmax(predictions[0])
        if(class_names[labels[i]]==class_names[np.argmax(score)]):
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'green'})
            
        else:
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'red'})
        plt.gca().axes.yaxis.set_ticklabels([])        
        plt.gca().axes.xaxis.set_ticklabels([])
# Out:
# 1/1 [==============================] - 1s 683ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step

# %%
#from keras.models import load_model
model.save("alzheimersmine.h5")
